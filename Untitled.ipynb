# %%
import sklearn
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import LabelEncoder
import numpy as np
from typing import Dict, Tuple
from scipy import stats
from sklearn.metrics import accuracy_score, balanced_accuracy_score
from sklearn.metrics import precision_score, recall_score, f1_score, classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import mean_absolute_error, mean_squared_error, mean_squared_log_error, median_absolute_error, r2_score 
from sklearn.metrics import roc_curve, roc_auc_score
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
from sklearn.model_selection import cross_val_score, cross_validate, KFold, LeaveOneOut, GridSearchCV,learning_curve,validation_curve
import time
# %matplotlib inline 
sns.set(style="ticks")

from sklearn import preprocessing
from sklearn import utils

# %%
data = pd.read_csv('Распределение_за_которое_платим.csv', sep=";")

# %%
print(data)
# Out:
#          count1      address
# 0         21371  79030493000
# 1          1306  79851454197
# 2           925  79524424077
# 3           918  79500460703
# 4           879  79268693851
# 5           869  79160326605
# 6           866  79269300047
# 7           831  79509596153
# 8           798  79112636818
# 9           770  79296134637
# 10          765  79277537484
# 11          729  79689173402
# 12          721  79039784563
# 13          678  79112341055
# 14          666  79152028049
# 15          660  79163619674
# 16          631  79859284912
# 17          613  79771596272
# 18          610  79197113113
# 19          608  89168695457
# 20          592  79025676006
# 21          590  79691237755
# 22          590  79508032372
# 23          587  79778667346
# 24          584  79052035145
# 25          575  79648112070
# 26          572  79998536510
# 27          568  79259419982
# 28          567  79777982072
# 29          567  79992399058
# ...         ...          ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1434751 entries, 0 to 1434750
# Data columns (total 2 columns):
# count1     1434751 non-null int64
# address    1434751 non-null int64
# dtypes: int64(2)
# memory usage: 21.9 MB

# %%
data.drop([0], inplace=True)

# %%
import openpyxl
fig, ax = plt.subplots(figsize=(100,10))
rects1 = ax.plot(data['count1'][:1000])
rects1 = ax.grid(axis = 'both')
rects1 = ax.minorticks_on()
ax.grid(which='minor', 
        color = 'k', 
        linestyle = ':')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-b3edabfd9c65> in <module>
#      13 ws = wb.active
#      14
# ---> 15 img = openpyxl.drawing.Image('myplot.png')
#      16 img.anchor(ws.cell('A1'))
#      17
#
# AttributeError: module 'openpyxl.drawing' has no attribute 'Image'

# %%
fig, ax = plt.subplots(figsize=(100,10))
rects1 = ax.plot(data['count1'][:1000])
rects1 = ax.grid(axis = 'both')
rects1 = ax.minorticks_on()
ax.grid(which='minor', 
        color = 'k', 
        linestyle = ':')

# %%
fig, ax = plt.subplots(figsize=(100,10))
rects1 = ax.plot(data['count1'][:10000])
rects1 = ax.grid(axis = 'both')
rects1 = ax.minorticks_on()
ax.grid(which='minor', 
        color = 'k', 
        linestyle = ':')

# %%
fig, ax = plt.subplots(figsize=(250,100))
rects1 = ax.plot(data['count1'][:100000])
rects1 = ax.grid(axis = 'both')
rects1 = ax.minorticks_on()
ax.grid(which='minor', 
        color = 'k', 
        linestyle = ':')

# %%
fig, ax = plt.subplots(figsize=(100,10))
rects1 = ax.plot(data['count1'][:10000000])
rects1 = ax.grid(axis = 'both')
rects1 = ax.minorticks_on()
ax.grid(which='minor', 
        color = 'k', 
        linestyle = ':')

# %%
fig, ax = plt.subplots(figsize=(250,100))
rects1 = ax.plot(data['count1'][:1434750])
rects1 = ax.grid(axis = 'both')
rects1 = ax.minorticks_on()
ax.grid(which='minor', 
        color = 'r', 
        linestyle = ':')

# %%
data2.sum(axis = 0, skipna = True)
# Out:
# count1              15126581
# address    23537074971355702
# dtype: int64

# %%
data2 = data.iloc[:-1147800]
print(data2)
# Out:
#         count1      address
# 0        21371  79030493000
# 1         1306  79851454197
# 2          925  79524424077
# 3          918  79500460703
# 4          879  79268693851
# 5          869  79160326605
# 6          866  79269300047
# 7          831  79509596153
# 8          798  79112636818
# 9          770  79296134637
# 10         765  79277537484
# 11         729  79689173402
# 12         721  79039784563
# 13         678  79112341055
# 14         666  79152028049
# 15         660  79163619674
# 16         631  79859284912
# 17         613  79771596272
# 18         610  79197113113
# 19         608  89168695457
# 20         592  79025676006
# 21         590  79691237755
# 22         590  79508032372
# 23         587  79778667346
# 24         584  79052035145
# 25         575  79648112070
# 26         572  79998536510
# 27         568  79259419982
# 28         567  79777982072
# 29         567  79992399058
# ...        ...          ...
# 286921      16  79852437735
# ...

# %%
19188523-15105210
# Out:
# 4083313

# %%
15105210/19188523
# Out:
# 0.7872002446462398
